# %%
import numpy as np
from newton.newton import newtons_method
from bisection.bisection import bisect
from false_position.false_position import false_position
from secant.secant import secant_method

# %%
bisect(np.sin,2,4,1e-10,100000, table_output=True )
# Out:
# --------------------------------------------------------------------------------
# 		a		b		P		f(P)
# --------------------------------------------------------------------------------
# 1		2.0000000000	4.0000000000	3.0000000000	0.1411200081
#
# 2		3.0000000000	4.0000000000	3.5000000000	-0.3507832277
#
# 3		3.0000000000	3.5000000000	3.2500000000	-0.1081951345
#
# 4		3.0000000000	3.2500000000	3.1250000000	0.0165918922
#
# 5		3.1250000000	3.2500000000	3.1875000000	-0.0458912233
#
# 6		3.1250000000	3.1875000000	3.1562500000	-0.0146568216
#
# 7		3.1250000000	3.1562500000	3.1406250000	0.0009676534
#
# 8		3.1406250000	3.1562500000	3.1484375000	-0.0068447930
#
# 9		3.1406250000	3.1484375000	3.1445312500	-0.0029385922
#
# 10		3.1406250000	3.1445312500	3.1425781250	-0.0009854713
#
# 11		3.1406250000	3.1425781250	3.1416015625	-0.0000089089
#
# 12		3.1406250000	3.1416015625	3.1411132812	0.0004793723
#
# 13		3.1411132812	3.1416015625	3.1413574219	0.0002352317
#
# ...

# %%
np.cos(4)
# Out:
# -0.6536436208636119

# %%
newtons_method(np.sin,np.cos, 4, 1e-10,10000, table_output=True)
# Out:
# -------------------------------------
# n		P
# -------------------------------------
# 0		4.0000000000
#
# 1		2.8421787177
#
# 2		3.1508729397
#
# 3		3.1415923872
#
# 4		3.1415926536
#
# 5		3.1415926536
#
# -------------------------------------
# Approximate solution P = 3.1415926536
# f(P) = 0.0000000000
# Number of iterations = 5
# TOL = 1e-10
# 3.141592653589793

# %%
secant_method(np.sin,2,4,1e-10,1000,table_output=True)
# Out:
# -------------------------------------
# n		P
# -------------------------------------
# 0		2.0000000000
#
# 1		4.0000000000
#
# 2		2.0000000000
#
# 3		4.0000000000
#
# 4		3.0915280827
#
# 5		3.1478749574
#
# 6		3.1415903580
#
# -------------------------------------
# Approximate solution P = 3.1415926536
# f(P) = 0.0000000000
# Number of iterations = 6
# TOL = 1e-10
# 3.141592653589793

# %%
false_position(np.sin,2,4,1e-10,1000,table_output=True)
# Out:
# -------------------------------------
# n		P
# -------------------------------------
# 0		2.0000000000
#
# 1		4.0000000000
#
# 2		2.0000000000
#
# 3		4.0000000000
#
# 4		3.0915280827
#
# 5		3.1478749574
#
# 6		3.1415903580
#
# -------------------------------------
# Approximate solution P = 3.1415926536
# f(P) = 0.0000000000
# Number of iterations = 6
# TOL = 1e-10
# 3.141592653589793
